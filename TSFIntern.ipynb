# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h1><b>Importing the csv file from google drive</b></h1>

# %%
url='https://drive.google.com/file/d/1lV7is1B566UQPYzzY8R2ZmOritTW299S/view?usp=sharing'
url2='https://drive.google.com/uc?id=' + url.split('/')[-2]
df=pd.read_csv(url2)

# %%
df.head()  #Shows the top five rows
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()   #Shows the top five rows
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.shape  #Displays the rows and columns
# Out:
# (9994, 13)

# %%
df.describe()       #display summary
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.isnull().sum()       #checking null values
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()           #information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.duplicated().sum()
# Out:
# 17

# %%
#Since, duplicates are present ,we remove it
df.drop_duplicates(subset=None,keep='first',inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()   #Number of unique values
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
corr = df.corr()
sns.heatmap(corr,annot=True,cmap='rocket_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2><b>To plot multiple pairwise bivariate distributions</h2></b>

# %%
sns.pairplot(df, hue = 'Ship Mode')  #Plot the bivariables based on Ship mode categorical variable

# %%
sns.pairplot(df,hue = 'Segment')     #Plot the bivariables based on Segment categorical variable

# %%
sns.pairplot(df,hue='Category') #Plot the bivariables based on Category variable

# %%
#See the counts
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
#Count plot
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(df['Category'],ax=axs[0][0])
sns.countplot(df['Segment'],ax=axs[0][1])
sns.countplot(df['Ship Mode'],ax=axs[1][0])
sns.countplot(df['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)


plt.tight_layout()
# Out:
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# <h1><b>Statewise Deal Analysis</b></h1>

# %%
df['Country'].value_counts()
# Out:
# United States    9977
# Name: Country, dtype: int64

# %%
df1 = df['State'].value_counts()
df1.head(10)
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %%
df1.plot(kind='bar',figsize=(15,5))
plt.ylabel(' Number of deals in each state')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 30)
plt.show()

# %% [markdown]
# <h1><b>City wise Deal Analysis</b></h1>

# %%
df2 = df['City'].value_counts()
df2=df2.head(50)

# %%
df2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Number of deals')
plt.xlabel('City')

plt.title('City Wise Dealings', fontsize = 30)
plt.show()

# %% [markdown]
# <h1><b>Statewise analysis of Profit Discount and sales</b></h1>

# %%
df_state= df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            229.246629  0.072946   38.241878
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
df_state1=df_state.sort_values('Profit')

df_state1[['Profit']].plot(kind = 'bar', figsize = (15,4))
plt.title('State wise Profit Analysis', fontsize = 20)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %%
df_state1['Discount'].plot(kind='bar',figsize=(18,5))
plt.title('State wise analysis of Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %%
df_state['Sales'].plot(kind='pie',
                        figsize = (20,20),
                        autopct='%1.1f%%',
                        startangle=90,     # start angle 90° (Africa)
                        shadow=True)
plt.title('State wise analysis of Sale',fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Sale')

# %%
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.096896  0.074969    8.207059
# Binders        133.645972  0.372011   19.860710
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.971969  0.170244   43.198582
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.902745  0.138494   13.653476

# %% [markdown]
# <h2><b>Regionwise Analysis</b></h2>

# %%
df_region = df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.947759  0.240250  17.100421
# East     238.465798  0.145343  32.163905
# South    241.803645  0.147253  28.857673
# West     227.139254  0.109615  33.927281

# %%
df_region.plot.pie(subplots=True, 
                   figsize=(18, 20), 
                   autopct='%1.1f%%',  #to display the percent value
                   labels = df_region.index)
# Out:
# /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# <h2><b>Observation and Inference</b></h2>

# %% [markdown]
# 1)Profit and Discount is high in First Class
# 2)Highest dealing took place in cities California,New York and Texas
# 3)If discount is more profit is less
# 4)Vermont State has Highest Profit
# 5)Ohio state has Lowest Profit
# 6)Sales and Profit are Moderately Correlated.
# 7)Quantity and Profit are less Moderately Correlated.
# 8)Discount and Profit are Negatively Correlated
# 9)As sale increases,Discount decreases
# 10)Consumers make up the large amount of sales
# 11)For technology ,profit increases with sales
